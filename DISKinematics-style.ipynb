# %%
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('tdrstyle.mplstyle')

# %%
def Q2vsXEp(x,Ep, Elep, Ehad):
    s = 4.0*Elep*Ehad
    #    print("center of mass squared is: ",s)
    tempQ2 = ((1-Ep/Elep)/((1/(s*x))-(1/(4*Elep*Elep))))
    if tempQ2 > 0 :
         y = tempQ2/(s*x)
         if y > 1 :
           print("exceed y=1")
           return s*x
         else : 
           return tempQ2
    else:
         print("negative Q2")
         return 1

# %%
print("Q2 is: ",Q2vsXEp(0.057,45.0,30.0,820.))
# Out:
# Q2 is:  5025.8064516129025

# %%
def Q2vsXTh(x,TheDeg, Elep, Ehad):
    s = 4.0*Elep*Ehad
    Theta = (TheDeg/180.)*np.pi
    tempQ2 = s/((1/x)+Ehad/Elep*( (1-np.cos(Theta))/(1+np.cos(Theta)) ))
    return tempQ2

# %%
print("Q2 is: ",Q2vsXTh(0.1,150.,30.0,820.))
# Out:
# Q2 is:  251.85292237207372

# %%
def Q2vsXEhadp(x,Ep, Elep, Ehad):
    s = 4.0*Elep*Ehad
    #    print("center of mass squared is: ",s)
    #tempQ2 = (((s*x)-4.0*Ep*Elep)/(1.0 - 4*Elep*Elep/(s*x)))
    tempy = Ep/Elep
    if x < Elep/Ehad and tempy > Ehad/Elep :
      tempQ2 = s*x*tempy # approx result for large y
    else :
      tempQ2 = (((s*x)-4.0*Ep*Elep)/(1.0 - 4*Elep*Elep/(s*x)))
    if tempQ2 > 0 :
         y = tempQ2/(s*x)
         if y > 1 :
           print("exceed y=1")
           return s*x
         else : 
           return tempQ2
    else:
         print("negative Q2")
         return 1
#         return -tempQ2

# %%
print("Q2 is: ",Q2vsXEhadp(0.1,75.0,30.0,820.))
# Out:
# Q2 is:  1324.6153846153845

# %%
def Q2vsXThHad(x,TheDeg, Elep, Ehad):
    s = 4.0*Elep*Ehad
    Theta = (TheDeg/180.)*np.pi
    tempQ2 = s*x/((1) +Elep/(x*Ehad)*( (1+np.cos(Theta))/(1-np.cos(Theta)) ))
    return tempQ2

# %%
print("Q2 is: ",Q2vsXThHad(0.2,17.2,30.0,820.))
# Out:
# Q2 is:  2187.211340494541

# %% [markdown]
# Let's do HERA first, scattered lepton energy plot

# %%
# E' > E
Elep = 30
Ehad = 820
Ep0 = 31
Ep1 = 40
Ep2 = 60
Ep3 = 125
Ep4 = 250
Ep5 = 500
# E' < E
Em0 = 29
Em1 = 15

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  Q20[i] = Q2vsXEp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
# Out:
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1

# %%
print(x1)
print(Q21)
# Out:
# [0.048780487804878044, 0.0567327495318323, 0.06598139982355317, 0.07673777771396117, 0.08924767501484943, 0.10379695285477432, 0.12071807383378505, 0.140397699058936, 0.16328552365890175, 0.18990455267624828, 0.2208630521496931, 0.2568684484781134, 0.29874349367785313, 0.3474450659223484, 0.404086034971393, 0.46996069213253694, 0.5465743258495163, 0.6356776187434894, 0.7393066521069023, 0.8598294319845665]
# [4799.999999999999, 3379.0640276509453, 2693.4817080886505, 2293.3948171565535, 2033.65958925219, 1853.1974765550676, 1721.8236768839138, 1622.9019584559182, 1546.506585192062, 1486.34667280874, 1438.2406676946373, 1399.3000937763175, 1367.465488820669, 1341.2291108004322, 1319.462201605748, 1301.3035038273931, 1286.0850772627446, 1273.2816003088315, 1262.4748956424364, 1253.3285824102238]

# %%
xrange1 = [0.0002, 1.0]
yrange1 = [0.0002, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEp(xrange2[1]+0.0001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('HERA ep 30 x 820 GeV, Constant Elep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.855, 0.44, '31')
plt.figtext(0.855, 0.57, '40')
plt.figtext(0.855, 0.65, '60')
plt.figtext(0.855, 0.72, '125')
plt.figtext(0.855, 0.78, '250')
plt.figtext(0.855, 0.82, '500')
plt.figtext(0.2, 0.18, '29')
plt.figtext(0.2, 0.34, '15')
plt.grid()
plt.show()

# %% [markdown]
# Now the HERA lepton scattering angle plot

# %%
Elep = 30
Ehad = 820
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
Th1 = 177.0
Th2 = 175.0
Th3 = 170.0
Th4 = 160.0
Th5 = 140.0
Th6 = 90.0
Th7 = 40.0
Th8 = 20.0
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.0004, 1.0]
yrange1 = [0.0004, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('HERA ep 30 x 820 GeV, Constant Theta')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.85, 0.15, '177')
plt.figtext(0.85, 0.22, '175')
plt.figtext(0.85, 0.3, '170')
plt.figtext(0.85, 0.4, '160')
plt.figtext(0.85, 0.48, '140')
plt.figtext(0.85, 0.6, '90')
plt.figtext(0.85, 0.72, '40')
plt.figtext(0.85, 0.78, '20')
plt.grid()
plt.show()

# %% [markdown]
# Now let's do LHeC

# %%
# E' > E
Elep = 60
Ehad = 7000
Ep0 = 63
Ep1 = 80
Ep2 = 125
Ep3 = 250
Ep4 = 500
Ep5 = 1000
# E' < E
Em0 = 57
Em1 = 30

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  Q20[i] = Q2vsXEp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
# Out:
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEp(xrange2[1]+0.000001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant Elep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.855, 0.48, '63')
plt.figtext(0.855, 0.57, '80')
plt.figtext(0.855, 0.62, '125')
plt.figtext(0.855, 0.68, '250')
plt.figtext(0.855, 0.72, '500')
plt.figtext(0.855, 0.76, '1000')
plt.figtext(0.13, 0.15, '57')
plt.figtext(0.13, 0.25, '30')
plt.grid()
plt.show()

# %% [markdown]
# Now the LHeC scattering angle plots

# %%
Elep = 60
Ehad = 7000
nx = 20
xmax = 1.0  # for E'> E
xmin = 1E-5 # For E' < E
Th0 = 179.90
Th1 = 179.72
Th2 = 177.9
Th3 = 174.3
Th4 = 164.6
Th5 = 139.6
Th6 = 90.0
Th7 = 40.4
Th8 = 15.4
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th0 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th0[i] = Q2vsXTh(xTh[i],Th0, Elep, Ehad)
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.0004, 1.0]
yrange1 = [0.0004, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
#plt.plot(xTh, Q2Th0, 'r')
#plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
#plt.figtext(0.84, 0.15, '179.90')
#plt.figtext(0.84, 0.22, '179.72')
plt.figtext(0.84, 0.16, '-4')
plt.figtext(0.84, 0.27, '-3')
plt.figtext(0.84, 0.38, '-2')
plt.figtext(0.84, 0.48, '-1')
plt.figtext(0.84, 0.58, '0')
plt.figtext(0.84, 0.68, '1')
plt.figtext(0.84, 0.76, '2')
plt.grid()
plt.show()

# %% [markdown]
# Combined Plot

# %%
plt.plot(xrange1, yrange1, 'k')
#plt.plot(xTh, Q2Th0, 'r')
#plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r--')
plt.plot(xTh, Q2Th3, 'r--')
plt.plot(xTh, Q2Th4, 'r--')
plt.plot(xTh, Q2Th5, 'r--')
plt.plot(xTh, Q2Th6, 'r--')
plt.plot(xTh, Q2Th7, 'r--')
plt.plot(xTh, Q2Th8, 'r--')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'b--')
plt.plot(x1, Q21, 'b--')
plt.plot(x2, Q22, 'b--')
plt.plot(x3, Q23, 'b--')
plt.plot(x4, Q24, 'b--')
plt.plot(x5, Q25, 'b--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant E - Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
#plt.figtext(0.84, 0.15, '179.90')
#plt.figtext(0.84, 0.22, '179.72')
plt.figtext(0.74, 0.2, '-4')
plt.figtext(0.74, 0.31, '-3')
plt.figtext(0.74, 0.41, '-2')
plt.figtext(0.74, 0.51, '-1')
plt.figtext(0.74, 0.60, '0')
plt.figtext(0.74, 0.68, '1')
plt.figtext(0.74, 0.72, '2')
plt.figtext(0.855, 0.48, '63')
plt.figtext(0.855, 0.57, '80')
plt.figtext(0.855, 0.62, '125')
plt.figtext(0.855, 0.68, '250')
plt.figtext(0.855, 0.72, '500')
plt.figtext(0.855, 0.76, '1000')
plt.figtext(0.13, 0.15, '57')
plt.figtext(0.13, 0.25, '30')
plt.grid()
plt.show()

# %% [markdown]
# Now the Muon-Ion Collider

# %%
# E' < E always
Elep = 1000
Ehad = 275
# E' < E
Em0 = 990
Em1 = 980
Em2 = 900
Em3 = 500
Em4 = 250

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
xmax0 = xmax
xmax1 = xmax
xmax2 = xmax
xmax3 = xmax
xmax4 = xmax
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logxmax3 = np.log(xmax3)
logxmax4 = np.log(xmax4)
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
logxm3 = [0] * nx
logxm4 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
xm3 = [0] * nx
xm4 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
Q2m3 = [0] * nx
Q2m4 = [0] * nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx
dlogxm3 = (np.log(xmax3)-np.log(xmin))/nx
dlogxm4 = (np.log(xmax4)-np.log(xmin))/nx

# %%
for i in range(nx):
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  logxm3[i] = logxmax3 - dlogxm3*i
  logxm4[i] = logxmax4 - dlogxm4*i
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  xm3[i] = np.exp(logxm3[i])
  xm4[i] = np.exp(logxm4[i])
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEp(xm2[i],Em2, Elep, Ehad)
  Q2m3[i] = Q2vsXEp(xm3[i],Em3, Elep, Ehad)
  Q2m4[i] = Q2vsXEp(xm4[i],Em4, Elep, Ehad)
# Out:
# exceed y=1

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-5, 1.0]
yrange3 = [1E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.plot(xm3, Q2m3, 'b')
#plt.plot(xm4, Q2m4, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant Elep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.23, 0.18, '990', fontsize=8)
plt.figtext(0.14, 0.21, '980', fontsize=8)
plt.figtext(0.23, 0.28, '900', fontsize=8)
plt.figtext(0.14, 0.30, '500', fontsize=8)
#plt.figtext(0.13, 0.335, '250')
plt.plot(xrange3, yrange3, 'k--')
plt.grid()
plt.show()

# %% [markdown]
# Now MuIC scattering angles

# %%
Elep = 1000
Ehad = 275
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
Th0 = 179.962 # eta = -8
Th1 = 179.90 # eta = -7
Th2 = 179.72 # eta = -6
Th3 = 179.23 # eta = -5 
Th4 = 177.9 # eta = -4
Th5 = 174.3 # eta = -3
Th6 = 164.6 # eta = -2
Th7 = 139.6 # eta = -1
Th8 = 90.0 # eta = 0
#Th8 = 40.4 # eta = 1
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th0 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th0[i] = Q2vsXTh(xTh[i],Th0, Elep, Ehad)
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.00001, 1.0]
yrange1 = [0.00001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [4E-5, 1.0]
yrange3 = [4E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh, Q2Th0, 'r')
plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant Eta')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.15, '-8', fontsize=8)
plt.figtext(0.84, 0.25, '-7', fontsize=8)
plt.figtext(0.84, 0.34, '-6', fontsize=8)
plt.figtext(0.84, 0.43, '-5', fontsize=8) 
plt.figtext(0.84, 0.52, '-4', fontsize=8) 
plt.figtext(0.84, 0.61, '-3', fontsize=8) 
plt.figtext(0.84, 0.70, '-2', fontsize=8) 
plt.figtext(0.84, 0.76, '-1', fontsize=8)
plt.figtext(0.84, 0.80, '0', fontsize=8) 
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
plt.plot(xrange1, yrange1, 'k')
#Eta values
plt.plot(xTh, Q2Th0, 'r--')
plt.plot(xTh, Q2Th1, 'r--')
plt.plot(xTh, Q2Th2, 'r--')
plt.plot(xTh, Q2Th3, 'r--')
plt.plot(xTh, Q2Th4, 'r--')
plt.plot(xTh, Q2Th5, 'r--')
plt.plot(xTh, Q2Th6, 'r--')
plt.plot(xTh, Q2Th7, 'r--')
plt.plot(xTh, Q2Th8, 'r--')
# Energies
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.plot(xm3, Q2m3, 'b--')
#plt.plot(xm4, Q2m4, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant E - Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.23, '-8', fontsize=8)
plt.figtext(0.84, 0.32, '-7', fontsize=8)
plt.figtext(0.84, 0.40, '-6', fontsize=8)
plt.figtext(0.84, 0.49, '-5', fontsize=8) 
plt.figtext(0.84, 0.56, '-4', fontsize=8) 
plt.figtext(0.84, 0.61, '-3', fontsize=8) 
plt.figtext(0.84, 0.71, '-2', fontsize=8) 
plt.figtext(0.84, 0.77, '-1', fontsize=8)
plt.figtext(0.85, 0.80, '0', fontsize=8) 
plt.figtext(0.15, 0.15, '990', fontsize=8)
plt.figtext(0.15, 0.19, '980', fontsize=8)
plt.figtext(0.15, 0.24, '900', fontsize=8)
plt.figtext(0.15, 0.30, '500', fontsize=8)
#plt.figtext(0.13, 0.335, '250')
plt.plot(xrange3, yrange3, 'k')
plt.grid()
plt.show()

# %% [markdown]
# Now hadron variables, HERA first, lepton scattered energy

# %%
# E' > E
Elep = 30
Ehad = 820
Ep0 = 31
Ep1 = 40
Ep2 = 60
Ep3 = 125
Ep4 = 250
Ep5 = 500
# E' < E
Em0 = 29
Em1 = 15
Em2 = 7.5

# %%
nx = 40
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
xmax2 = Em2/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  Q20[i] = Q2vsXEhadp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEhadp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEhadp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEhadp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEhadp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEhadp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
# Out:
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2

# %%
xrange1 = [0.0002, 1.0]
yrange1 = [0.0002, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEhadp(xrange2[1]-0.0001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('HERA ep 30 x 820 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.59, 0.18, '31')
plt.figtext(0.62, 0.18, '40')
plt.figtext(0.65, 0.18, '60')
plt.figtext(0.71, 0.18, '125')
plt.figtext(0.77, 0.18, '250')
plt.figtext(0.83, 0.18, '500')
plt.figtext(0.48, 0.18, '7.5')
plt.figtext(0.53, 0.18, '15')
plt.figtext(0.56, 0.18, '29')
plt.grid()
plt.show()

# %% [markdown]
# Now the HERA hadron scattering angle plot

# %%
Elep = 30
Ehad = 820
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
Th1 = 170.0
Th2 = 160.0
Th3 = 140.0
Th4 = 90.0
Th5 = 40.0
Th6 = 20.0
Th7 = 10.0
Th8 = 5.0
xmin1 = xmin
xmin2 = xmin
xmin3 = xmin
xmin4 = 6E-4
xmin5 = 1.8E-3
xmin6 = 3.4E-3
xmin7 = 7E-3
xmin8 = 1.5E-2
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.001, 1.0]
yrange1 = [0.001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh1, Q2Th1, 'r')
plt.plot(xTh2, Q2Th2, 'r')
plt.plot(xTh3, Q2Th3, 'r')
plt.plot(xTh4, Q2Th4, 'r')
plt.plot(xTh5, Q2Th5, 'r')
plt.plot(xTh6, Q2Th6, 'r')
plt.plot(xTh7, Q2Th7, 'r')
plt.plot(xTh8, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('HERA ep 30 x 820 GeV, Constant Gamma')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.14, 0.38, '170')
plt.figtext(0.18, 0.3, '160')
plt.figtext(0.17, 0.22, '140')
plt.figtext(0.24, 0.18, '90')
plt.figtext(0.33, 0.18, '40')
plt.figtext(0.39, 0.18, '20')
plt.figtext(0.45, 0.18, '10')
plt.figtext(0.52, 0.18, '5')
plt.grid()
plt.show()

# %% [markdown]
# Now let's do LHeC Hadron variables

# %%
Elep = 60
Ehad = 7000
Ep0 = 63
Ep1 = 125
Ep2 = 250
Ep3 = 500
Ep4 = 1000
Ep5 = 2000
# E' < E
Em0 = 57
Em1 = 30
Em2 = 15

# %%
nx = 60
xmax = 1.0  # for E'> E
xmin = 1E-5 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad*1.00005
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad*0.9999
xmax1 = Em1/Ehad*0.9999
xmax2 = Em2/Ehad*0.9995
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  Q20[i] = Q2vsXEhadp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEhadp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEhadp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEhadp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEhadp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEhadp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
# Out:
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEhadp(xrange2[1]-0.000001,(Elep+1), Elep, Ehad)
# Out:
# exceed y=1

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.58, 0.2, '63')
plt.figtext(0.61, 0.15, '125')
plt.figtext(0.65, 0.20, '250')
plt.figtext(0.69, 0.15, '500')
plt.figtext(0.74, 0.20, '1000')
plt.figtext(0.78, 0.15, '2000')
plt.figtext(0.49, 0.2, '15')
plt.figtext(0.54, 0.15, '30')
plt.figtext(0.54, 0.2, '57')
plt.grid()
plt.show()

# %% [markdown]
# Now the LHeC hadron scattering angle plot

# %%
Elep = 60
Ehad = 7000
nx = 60
xmax = 1.0  # for E'> E
xmin = 4E-5 # For E' < E
Th1 = 164.6 # eta = -2
Th2 = 140.0 # eta = -1 
Th3 = 90.0 # eta = 0
Th4 = 40.4 # eta = 1
Th5 = 15.4 # eta = 2
Th6 = 5.7 # eta = 3
Th7 = 2.1 # eta = 4
Th8 = 0.772 # eta = 5
xmin1 = xmin
xmin2 = xmin
xmin3 = 4.0E-5
xmin4 = 1.0E-4
xmin5 = 4.0E-4
xmin6 = 1.0E-3
xmin7 = 4.0E-3
xmin8 = 1.0E-2
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.00001, 1.0]
yrange1 = [0.00001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh1, Q2Th1, 'r')
plt.plot(xTh2, Q2Th2, 'r')
plt.plot(xTh3, Q2Th3, 'r')
plt.plot(xTh4, Q2Th4, 'r')
plt.plot(xTh5, Q2Th5, 'r')
plt.plot(xTh6, Q2Th6, 'r')
plt.plot(xTh7, Q2Th7, 'r')
plt.plot(xTh8, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.20, 0.30, '-2')
plt.figtext(0.20, 0.24, '-1')
plt.figtext(0.29, 0.18, '0')
plt.figtext(0.33, 0.18, '1')
plt.figtext(0.40, 0.18, '2')
plt.figtext(0.46, 0.18, '3')
plt.figtext(0.53, 0.18, '4')
plt.figtext(0.60, 0.18, '5')
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh1, Q2Th1, 'r--')
plt.plot(xTh2, Q2Th2, 'r--')
plt.plot(xTh3, Q2Th3, 'r--')
plt.plot(xTh4, Q2Th4, 'r--')
plt.plot(xTh5, Q2Th5, 'r--')
plt.plot(xTh6, Q2Th6, 'r--')
plt.plot(xTh7, Q2Th7, 'r--')
plt.plot(xTh8, Q2Th8, 'r--')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'b--')
plt.plot(x1, Q21, 'b--')
plt.plot(x2, Q22, 'b--')
plt.plot(x3, Q23, 'b--')
plt.plot(x4, Q24, 'b--')
plt.plot(x5, Q25, 'b--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.yscale('log')
plt.xscale('log')
plt.title('LHeC ep 60 x 7000 GeV, Constant Ehad - Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.22, 0.30, '-2')
plt.figtext(0.22, 0.24, '-1')
plt.figtext(0.27, 0.17, '0')
plt.figtext(0.33, 0.17, '1')
plt.figtext(0.40, 0.17, '2')
plt.figtext(0.46, 0.17, '3')
plt.figtext(0.53, 0.17, '4')
plt.figtext(0.60, 0.17, '5')
plt.figtext(0.58, 0.2, '63')
plt.figtext(0.61, 0.20, '125')
plt.figtext(0.65, 0.25, '250')
plt.figtext(0.69, 0.20, '500')
plt.figtext(0.74, 0.25, '1000')
plt.figtext(0.78, 0.20, '2000')
plt.figtext(0.49, 0.2, '15')
#plt.figtext(0.54, 0.15, '30')
plt.figtext(0.54, 0.2, '30')
plt.grid()
plt.show()

# %% [markdown]
# Now let's do MuIC Hadron variables

# %%
Elep = 1000
Ehad = 275
Em0 = 274.8
Em1 = 160
Em2 = 40
Em3 = 10
Em4 = 2.5
Em5 = 500

# %%
nx = 60
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
xmax2 = Em2/Ehad
xmax3 = Em3/Ehad*0.999
xmax4 = Em4/Ehad*0.999
xmax5 = xmax
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logxmax3 = np.log(xmax3)
logxmax4 = np.log(xmax4)
logxmax5 = np.log(xmax5)
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
logxm3 = [0] * nx
logxm4 = [0] * nx
logxm5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
xm3 = [0] * nx
xm4 = [0] * nx
xm5 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
Q2m3 = [0] * nx
Q2m4 = [0] * nx
Q2m5 = [0] * nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx
dlogxm3 = (np.log(xmax3)-np.log(xmin))/nx
dlogxm4 = (np.log(xmax4)-np.log(xmin))/nx
dlogxm5 = (np.log(xmax5)-np.log(xmin))/nx

# %%
for i in range(nx):
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  logxm3[i] = logxmax3 - dlogxm3*i
  logxm4[i] = logxmax4 - dlogxm4*i
  logxm5[i] = logxmax5 - dlogxm5*i
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  xm3[i] = np.exp(logxm3[i])
  xm4[i] = np.exp(logxm4[i])
  xm5[i] = np.exp(logxm5[i])
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
  Q2m3[i] = Q2vsXEhadp(xm3[i],Em3, Elep, Ehad)
  Q2m4[i] = Q2vsXEhadp(xm4[i],Em4, Elep, Ehad)
  Q2m5[i] = Q2vsXEhadp(xm5[i],Em5, Elep, Ehad)
# Out:
# negative Q2
# negative Q2
# negative Q2

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-5, 1.0]
yrange3 = [1E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.plot(xm3, Q2m3, 'b')
#plt.plot(xm4, Q2m4, 'b')
plt.plot(xm5, Q2m5, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.85, 0.78, '500', fontsize=8)
plt.figtext(0.84, 0.26, '275', fontsize=8)
plt.figtext(0.78, 0.26, '160', fontsize=8)
plt.figtext(0.72, 0.26, '40', fontsize=8)
plt.figtext(0.64, 0.26, '10', fontsize=8)
#plt.figtext(0.55, 0.28, '2.5')
plt.grid()
plt.show()

# %% [markdown]
# Now the MuIC hadron scattering angle plot

# %%
Elep = 1000
Ehad = 275
nx = 60
xmax = 1.0  # for E'> E
xmin = 4E-5 # For E' < E
Th1 = 177.9 # eta = -4
Th2 = 174.3 # eta = -3
Th3 = 164.6 # eta = -2
Th4 = 140.0 # eta = -1 
Th5 = 90.0 # eta = 0
Th6 = 40.4 # eta = 1
Th7 = 15.4 # eta = 2
Th8 = 5.7 # eta = 3
#Th7 = 2.1 # eta = 4
#Th8 = 0.772 # eta = 5
xmin1 = xmin
xmin2 = xmin
xmin3 = 0.0001
xmin4 = 0.0004
xmin5 = 0.001
xmin6 = 0.004
xmin7 = 0.01
xmin8 = 0.04
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.00001, 1.0]
yrange1 = [0.00001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [4E-5, 1.0]
yrange3 = [4E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh1, Q2Th1, 'r')
plt.plot(xTh2, Q2Th2, 'r')
plt.plot(xTh3, Q2Th3, 'r')
plt.plot(xTh4, Q2Th4, 'r')
plt.plot(xTh5, Q2Th5, 'r')
plt.plot(xTh6, Q2Th6, 'r')
plt.plot(xTh7, Q2Th7, 'r')
plt.plot(xTh8, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.2, 0.18, '-4', fontsize=8)
plt.figtext(0.28, 0.18, '-3', fontsize=8)
plt.figtext(0.34, 0.18, '-2', fontsize=8)
plt.figtext(0.4, 0.18, '-1', fontsize=8)
plt.figtext(0.46, 0.18, '0', fontsize=8)
plt.figtext(0.53, 0.18, '1', fontsize=8)
plt.figtext(0.6, 0.18, '2', fontsize=8)
plt.figtext(0.67, 0.18, '3', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k')
plt.plot(xTh1, Q2Th1, 'r--')
plt.plot(xTh2, Q2Th2, 'r--')
plt.plot(xTh3, Q2Th3, 'r--')
plt.plot(xTh4, Q2Th4, 'r--')
plt.plot(xTh5, Q2Th5, 'r--')
plt.plot(xTh6, Q2Th6, 'r--')
plt.plot(xTh7, Q2Th7, 'r--')
plt.plot(xTh8, Q2Th8, 'r--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.plot(xm3, Q2m3, 'b--')
#plt.plot(xm4, Q2m4, 'b--')
plt.plot(xm5, Q2m5, 'b--')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC mu-p 1000 x 275 GeV, Constant Ehad - Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.27, 0.27, '-4', fontsize=8)
plt.figtext(0.27, 0.22, '-3', fontsize=8)
plt.figtext(0.33, 0.24, '-2', fontsize=8)
plt.figtext(0.39, 0.24, '-1', fontsize=8)
plt.figtext(0.45, 0.24, '0', fontsize=8)
plt.figtext(0.53, 0.24, '1', fontsize=8)
plt.figtext(0.58, 0.24, '2', fontsize=8)
plt.figtext(0.64, 0.24, '3', fontsize=8)
plt.figtext(0.85, 0.78, '500', fontsize=8)
plt.figtext(0.85, 0.25, '275', fontsize=8)
plt.figtext(0.79, 0.25, '160', fontsize=8)
plt.figtext(0.74, 0.25, '40', fontsize=8)
plt.figtext(0.68, 0.25, '10', fontsize=8)
#plt.figtext(0.55, 0.28, '2.5', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Now return to MuIC at ~HERA c.o.m. (332 GeV vs 318 GeV) with 100 GeV muon beam, scattered lepton energy

# %%
# E' > E
Elep = 100
Ehad = 275
Ep0 = 103
Ep1 = 125
Ep2 = 200
# E' < E
Em0 = 97
Em1 = 80
Em2 = 50

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
xmax2 = Em2/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  Q20[i] = Q2vsXEp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEp(x2[i],Ep2, Elep, Ehad)
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEp(xm2[i],Em2, Elep, Ehad)
# Out:
# exceed y=1
# exceed y=1
# exceed y=1

# %%
xrange1 = [0.0002, 1.0]
yrange1 = [0.0002, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEp(xrange2[1]+0.0001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC (HERA overlap) mu-p 100 x 275 GeV, Constant E_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.855, 0.55, '95', fontsize=8)
plt.figtext(0.855, 0.70, '125', fontsize=8)
plt.figtext(0.855, 0.78, '200', fontsize=8)
plt.figtext(0.2, 0.18, '90', fontsize=8)
plt.figtext(0.2, 0.26, '80', fontsize=8)
plt.figtext(0.2, 0.32, '50', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Now MuIC at HERA energy scattered lepton angle

# %%
Elep = 100
Ehad = 275
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
Th1 = 178.73 # eta = -4.5
Th2 = 177.9 # eta = -4
Th3 = 174.3 # eta = -3
Th4 = 164.6 # eta = -2
Th5 = 139.6 # eta = -1
Th6 = 90.0 # eta = 0
Th7 = 40.4 # eta = +1
Th8 = 15.4 # eta = +2
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.0004, 1.0]
yrange1 = [0.0004, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
#plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC (HERA overlap) mu-p 100 x 275 GeV, Constant Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.15, '-4.5', fontsize=8)
plt.figtext(0.84, 0.22, '-4', fontsize=8)
plt.figtext(0.84, 0.35, '-3', fontsize=8)
plt.figtext(0.84, 0.48, '-2', fontsize=8)
plt.figtext(0.84, 0.62, '-1', fontsize=8)
plt.figtext(0.84, 0.72, '0', fontsize=8)
plt.figtext(0.84, 0.78, '1', fontsize=8)
#plt.figtext(0.84, 0.78, '2')
plt.grid()
plt.show()

# %% [markdown]
# Combined plot, MuIC (HERA overlap)

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'r--')
plt.plot(x0, Q20, 'r--')
plt.plot(x1, Q21, 'r--')
plt.plot(x2, Q22, 'r--')
plt.plot(xm0, Q2m0, 'r--')
plt.plot(xm1, Q2m1, 'r--')
plt.plot(xm2, Q2m2, 'r--')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC (HERA overlap) mu-p 100 x 275 GeV, Constant E_lep, Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.845, 0.575, '103', fontsize=8)
plt.figtext(0.845, 0.705, '125', fontsize=8)
plt.figtext(0.845, 0.785, '200', fontsize=8)
plt.figtext(0.72, 0.20, '100', fontsize=8)
plt.figtext(0.17, 0.17, '97', fontsize=8)
plt.figtext(0.17, 0.26, '80', fontsize=8)
plt.figtext(0.17, 0.34, '50', fontsize=8)
#
plt.plot(xrange1, yrange1, 'k')
plt.plot(xTh, Q2Th1, 'b--')
plt.plot(xTh, Q2Th2, 'b--')
plt.plot(xTh, Q2Th3, 'b--')
plt.plot(xTh, Q2Th4, 'b--')
plt.plot(xTh, Q2Th5, 'b--')
plt.plot(xTh, Q2Th6, 'b--')
plt.plot(xTh, Q2Th7, 'b--')
#plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
#plt.title('MuIC (HERA overlap) mu-p 92 x 275 GeV, Constant Eta_lep')
#plt.ylabel('Q2')
#plt.xlabel('x')
plt.figtext(0.84, 0.24, '-4.5', fontsize=8)
plt.figtext(0.84, 0.31, '-4', fontsize=8)
plt.figtext(0.84, 0.42, '-3', fontsize=8)
plt.figtext(0.84, 0.53, '-2', fontsize=8)
plt.figtext(0.84, 0.65, '-1', fontsize=8)
plt.figtext(0.84, 0.75, '0', fontsize=8)
plt.figtext(0.83, 0.80, '1', fontsize=8)
#plt.figtext(0.84, 0.78, '2')
plt.grid()
plt.show()

# %% [markdown]
# Now return to MuIC at EIC c.o.m. 140 GeV, scattered lepton energy

# %%
# E' > E
Elep = 18
Ehad = 275
Ep0 = 19
Ep1 = 25
Ep2 = 40
Ep3 = 80
# E' < E
Em0 = 17
Em1 = 15
Em2 = 5

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
xmax2 = Em2/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  Q20[i] = Q2vsXEp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEp(x3[i],Ep3, Elep, Ehad)
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEp(xm2[i],Em2, Elep, Ehad)
# Out:
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1

# %%
xrange1 = [0.0002, 1.0]
yrange1 = [0.0002, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEp(xrange2[1]+0.0001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('EIC mu-p 18 x 275 GeV, Constant E_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.855, 0.50, '19')
plt.figtext(0.855, 0.62, '25')
plt.figtext(0.855, 0.70, '40')
plt.figtext(0.855, 0.78, '80')
plt.figtext(0.2, 0.15, '17')
plt.figtext(0.2, 0.23, '15')
plt.figtext(0.2, 0.28, '5')
plt.grid()
plt.show()

# %% [markdown]
# Now scattered lepton angle, EIC

# %%
Elep = 18
Ehad = 275
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
Th1 = 178.73 # eta = -4.5
Th2 = 177.9 # eta = -4
Th3 = 174.3 # eta = -3
Th4 = 164.6 # eta = -2
Th5 = 139.6 # eta = -1
Th6 = 90.0 # eta = 0
Th7 = 40.4 # eta = +1
Th8 = 15.4 # eta = +2
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.0004, 1.0]
yrange1 = [0.0004, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
#plt.plot(xTh, Q2Th1, 'r')
#plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('EIC mu-p 18 x 275 GeV, Constant Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
#plt.figtext(0.84, 0.15, '-4.5')
#plt.figtext(0.84, 0.22, '-4')
plt.figtext(0.84, 0.2, '-3')
plt.figtext(0.84, 0.35, '-2')
plt.figtext(0.84, 0.48, '-1')
plt.figtext(0.84, 0.62, '0')
plt.figtext(0.84, 0.72, '1')
plt.figtext(0.84, 0.78, '2')
plt.grid()
plt.show()

# %% [markdown]
# Combined EIC plot

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r--')
plt.plot(x1, Q21, 'r--')
plt.plot(x2, Q22, 'r--')
plt.plot(x3, Q23, 'r--')
plt.plot(xm0, Q2m0, 'r--')
plt.plot(xm1, Q2m1, 'r--')
plt.plot(xm2, Q2m2, 'r--')
plt.yscale('log')
plt.xscale('log')
plt.title('EIC mu-p 18 x 275 GeV, Constant E_lep, Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.865, 0.48, '19')
plt.figtext(0.865, 0.60, '25')
plt.figtext(0.865, 0.68, '40')
plt.figtext(0.865, 0.75, '80')
plt.figtext(0.2, 0.13, '17')
plt.figtext(0.2, 0.21, '15')
plt.figtext(0.2, 0.30, '5')

#
plt.plot(xrange1, yrange1, 'k')
#plt.plot(xTh, Q2Th1, 'b--')
#plt.plot(xTh, Q2Th2, 'b--')
plt.plot(xTh, Q2Th3, 'b--')
plt.plot(xTh, Q2Th4, 'b--')
plt.plot(xTh, Q2Th5, 'b--')
plt.plot(xTh, Q2Th6, 'b--')
plt.plot(xTh, Q2Th7, 'b--')
plt.plot(xTh, Q2Th8, 'b--')
plt.yscale('log')
plt.xscale('log')
#plt.ylabel('Q2')
#plt.xlabel('x')
#plt.figtext(0.83, 0.22, '-4.5')
#plt.figtext(0.83, 0.31, '-4')
plt.figtext(0.84, 0.25, '-3')
plt.figtext(0.84, 0.4, '-2')
plt.figtext(0.84, 0.50, '-1')
plt.figtext(0.84, 0.64, '0')
plt.figtext(0.84, 0.74, '1')
plt.figtext(0.84, 0.80, '2')
plt.grid()
plt.show()

# %% [markdown]
# Now hadron variables, MuIC (HERA overlap), hadron energy

# %%
# E' > E
Elep = 92
#Elep = 100
Ehad = 275
Ep0 = 95
Ep1 = 125
Ep2 = 200
# E' < E
Em0 = 90
Em1 = 40
Em2 = 20

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
xmax2 = Em2/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  Q20[i] = Q2vsXEhadp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEhadp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEhadp(x2[i],Ep2, Elep, Ehad)
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
# Out:
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2

# %%
xrange1 = [0.0002, 1.0]
yrange1 = [0.0002, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEhadp(xrange2[1]-0.0001,(Elep+0.1), Elep, Ehad)
# Out:
# exceed y=1

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC (HERA overlap) mu-p 92 x 275 GeV, Constant Ehad')
#plt.title('MuIC (HERA overlap) mu-p 100 x 275 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.77, 0.18, '95')
plt.figtext(0.8, 0.20, '125')
plt.figtext(0.84, 0.18, '200')
plt.figtext(0.66, 0.18, '20')
plt.figtext(0.71, 0.18, '40')
plt.figtext(0.74, 0.18, '90')
plt.grid()
plt.show()

# %% [markdown]
# Now the MuIC (HERA overlap) hadron scattering angle plot

# %%
Elep = 92
#Elep = 100
Ehad = 275
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-4 # For E' < E
#Th1 = 178.73 # eta = -4.5
Th1 = 177.9 # eta = -4
Th2 = 174.3 # eta = -3
Th3 = 164.6 # eta = -2
Th4 = 139.6 # eta = -1
Th5 = 90.0 # eta = 0
Th6 = 40.4 # eta = +1
Th7 = 15.4 # eta = +2
Th8 = 5.70 # eta = +3
xmin1 = xmin
xmin2 = xmin
#xmin3 = xmin
xmin3 = 6E-4
#xmin4 = 6E-4
xmin4 = 1E-3
xmin5 = 1.8E-3
xmin6 = 3.4E-3
xmin7 = 7E-3
xmin8 = 1.5E-2
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.001, 1.0]
yrange1 = [0.001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad

# %%
plt.plot(xrange1, yrange1, 'k')
#plt.plot(xTh, Q2Th1, 'r')
#plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC (HERA overlap) mu-p 92 x 275 GeV, Constant Eta_had')
#plt.title('MuIC (HERA overlap) mu-p 100 x 275 GeV, Constant Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')

#plt.figtext(0.84, 0.15, '-4.5')
#plt.figtext(0.13, 0.53, '-3')
plt.figtext(0.13, 0.31, '-2')
plt.figtext(0.13, 0.27, '-1')
plt.figtext(0.14, 0.24, '0')
plt.figtext(0.14, 0.20, '1')
plt.figtext(0.14, 0.17, '2')
plt.figtext(0.14, 0.14, '3')


plt.grid()
plt.show()

# %% [markdown]
# Now let's study an LHC - Muon (LHmuC) collider, sqrt(s) = 6.5 TeV

# %%
Elep = 1500
Ehad = 7000
Ep0 = 1600
Ep1 = 2000
Ep2 = 3000
Ep3 = 4000
Ep4 = 5000
Ep5 = 6000
# E' < E
Em0 = 1400
Em1 = 750
Em2 = 400

# %%
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-7 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad
xmax1 = Em1/Ehad
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  Q20[i] = Q2vsXEp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
# Out:
# exceed y=1

# %%
xrange1 = [1E-6, 1.0]
yrange1 = [1E-6, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEp(xrange2[1]+0.000001,(Elep+0.1), Elep, Ehad)
xrange3 = [4E-6, 1.0]
yrange3 = [4E-6, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01
# Out:
# exceed y=1

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(x0, Q20, 'r')
plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
plt.plot(x3, Q23, 'r')
plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant Elep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.66, '1600', fontsize=8)
plt.figtext(0.84, 0.72, '2000', fontsize=8)
plt.figtext(0.84, 0.77, '3000', fontsize=8)
#plt.figtext(0.85, 0.68, '4000', fontsize=8)
#plt.figtext(0.85, 0.72, '5000', fontsize=8)
#plt.figtext(0.85, 0.76, '6000', fontsize=8)
plt.figtext(0.15, 0.16, '1400', fontsize=8)
plt.figtext(0.15, 0.24, '750', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Now LHC - Muon scattering angles

# %%
Elep = 1500
Ehad = 7000
nx = 20
xmax = 1.0  # for E'> E
xmin = 1E-6 # For E' < E
Th0 = 179.962 # eta = -8
Th1 = 179.90 # eta = -7
Th2 = 179.72 # eta = -6
Th3 = 179.23 # eta = -5 
Th4 = 177.9 # eta = -4
Th5 = 174.3 # eta = -3
Th6 = 164.6 # eta = -2
Th7 = 139.6 # eta = -1
Th8 = 90.0 # eta = 0
#Th8 = 40.4 # eta = 1
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th0 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th0[i] = Q2vsXTh(xTh[i],Th0, Elep, Ehad)
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.000001, 1.0]
yrange1 = [0.000001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-6, 1.0]
yrange3 = [1E-6, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh, Q2Th0, 'r')
plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant Eta')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.17, '-8', fontsize=8)
plt.figtext(0.84, 0.25, '-7', fontsize=8)
plt.figtext(0.84, 0.32, '-6', fontsize=8)
plt.figtext(0.84, 0.40, '-5', fontsize=8) 
plt.figtext(0.84, 0.48, '-4', fontsize=8) 
plt.figtext(0.84, 0.55, '-3', fontsize=8) 
plt.figtext(0.84, 0.62, '-2', fontsize=8) 
plt.figtext(0.84, 0.70, '-1', fontsize=8)
plt.figtext(0.84, 0.77, '0', fontsize=8) 
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
xrange3 = [4E-6, 1.0]
yrange3 = [4E-6, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(xrange3, yrange3, 'b--')
#Eta values
plt.plot(xTh, Q2Th0, 'r--')
plt.plot(xTh, Q2Th1, 'r--')
plt.plot(xTh, Q2Th2, 'r--')
plt.plot(xTh, Q2Th3, 'r--')
plt.plot(xTh, Q2Th4, 'r--')
plt.plot(xTh, Q2Th5, 'r--')
plt.plot(xTh, Q2Th6, 'r--')
plt.plot(xTh, Q2Th7, 'r--')
plt.plot(xTh, Q2Th8, 'r--')
# Energies
plt.plot(x0, Q20, 'b--')
plt.plot(x1, Q21, 'b--')
plt.plot(x2, Q22, 'b--')
plt.plot(x3, Q23, 'b--')
plt.plot(x4, Q24, 'b--')
plt.plot(x5, Q25, 'b--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
#plt.plot(xm4, Q2m4, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant E - Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.835, 0.15, '-8', fontsize=8)
plt.figtext(0.835, 0.23, '-7', fontsize=8)
plt.figtext(0.835, 0.30, '-6', fontsize=8)
plt.figtext(0.835, 0.38, '-5', fontsize=8) 
plt.figtext(0.835, 0.46, '-4', fontsize=8) 
plt.figtext(0.835, 0.54, '-3', fontsize=8) 
plt.figtext(0.835, 0.62, '-2', fontsize=8) 
plt.figtext(0.835, 0.70, '-1', fontsize=8)
#plt.figtext(0.835, 0.77, '0', fontsize=8) 
plt.figtext(0.84, 0.67, '1600', fontsize=8)
plt.figtext(0.84, 0.73, '2000', fontsize=8)
plt.figtext(0.84, 0.77, '3000', fontsize=8)
plt.figtext(0.15, 0.17, '1400', fontsize=8)
plt.figtext(0.15, 0.24, '750', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Now hadron energies and angles for LHmuC

# %%
Elep = 1500
Ehad = 7000
Ep0 = 1600
Ep1 = 2000
Ep2 = 3000
Ep3 = 4000
Ep4 = 5000
Ep5 = 6000
# E' < E
Em0 = 1400
Em1 = 750
Em2 = 400
Em3 = 200
Em4 = 50

# %%
nx = 60
xmax = 1.0  # for E'> E
xmin = 1E-6 # For E' < E
xmin0 = Ep0/Ehad
xmin1 = Ep1/Ehad
xmin2 = Ep2/Ehad
xmin3 = Ep3/Ehad
xmin4 = Ep4/Ehad
xmin5 = Ep5/Ehad
xmax0 = Em0/Ehad*0.99999
xmax1 = Em1/Ehad*0.99999
xmax2 = Em2/Ehad*0.99999
xmax3 = Em3/Ehad*0.99999
xmax4 = Em4/Ehad*0.99995
logxmin0 = np.log(xmin0)
logxmin1 = np.log(xmin1)
logxmin2 = np.log(xmin2)
logxmin3 = np.log(xmin3)
logxmin4 = np.log(xmin4)
logxmin5 = np.log(xmin5)
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logxmax3 = np.log(xmax3)
logxmax4 = np.log(xmax4)
logx0 = [0] * nx
logx1 = [0] * nx
logx2 = [0] * nx
logx3 = [0] * nx
logx4 = [0] * nx
logx5 = [0] * nx
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
logxm3 = [0] * nx
logxm4 = [0] * nx
x0 = [0] * nx
x1 = [0] * nx
x2 = [0] * nx
x3 = [0] * nx
x4 = [0] * nx
x5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
xm3 = [0] * nx
xm4 = [0] * nx
Q20 = [0] * nx
Q21 = [0] * nx
Q22 = [0] * nx
Q23 = [0] * nx
Q24 = [0] * nx
Q25 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
Q2m3 = [0] * nx
Q2m4 = [0] * nx
dlogx0 = (np.log(xmax)-np.log(xmin0))/nx
dlogx1 = (np.log(xmax)-np.log(xmin1))/nx
dlogx2 = (np.log(xmax)-np.log(xmin2))/nx
dlogx3 = (np.log(xmax)-np.log(xmin3))/nx
dlogx4 = (np.log(xmax)-np.log(xmin4))/nx
dlogx5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx
dlogxm3 = (np.log(xmax3)-np.log(xmin))/nx
dlogxm4 = (np.log(xmax4)-np.log(xmin))/nx

# %%
for i in range(nx):
  logx0[i] = logxmin0 + dlogx0*i
  logx1[i] = logxmin1 + dlogx1*i
  logx2[i] = logxmin2 + dlogx2*i
  logx3[i] = logxmin3 + dlogx3*i
  logx4[i] = logxmin4 + dlogx4*i
  logx5[i] = logxmin5 + dlogx5*i
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  logxm3[i] = logxmax3 - dlogxm3*i
  logxm4[i] = logxmax4 - dlogxm4*i
  x0[i] = np.exp(logx0[i])
  x1[i] = np.exp(logx1[i])
  x2[i] = np.exp(logx2[i])
  x3[i] = np.exp(logx3[i])
  x4[i] = np.exp(logx4[i])
  x5[i] = np.exp(logx5[i])
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  xm3[i] = np.exp(logxm3[i])
  xm4[i] = np.exp(logxm4[i])
  Q20[i] = Q2vsXEhadp(x0[i],Ep0, Elep, Ehad)
  Q21[i] = Q2vsXEhadp(x1[i],Ep1, Elep, Ehad)
  Q22[i] = Q2vsXEhadp(x2[i],Ep2, Elep, Ehad)
  Q23[i] = Q2vsXEhadp(x3[i],Ep3, Elep, Ehad)
  Q24[i] = Q2vsXEhadp(x4[i],Ep4, Elep, Ehad)
  Q25[i] = Q2vsXEhadp(x5[i],Ep5, Elep, Ehad)
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
  Q2m3[i] = Q2vsXEhadp(xm3[i],Em3, Elep, Ehad)
  Q2m4[i] = Q2vsXEhadp(xm4[i],Em4, Elep, Ehad)
# Out:
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2
# negative Q2

# %%
xrange1 = [1E-6, 1.0]
yrange1 = [1E-6, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange2 = [0.000, 1.0]
xrange2[0] = Elep/Ehad
xrange2[1] = Elep/Ehad
yrange2 = [1.0, 1.0]
yrange2[0] = 1.0
yrange2[1] = Q2vsXEhadp(xrange2[1]-0.000001,(Elep+1), Elep, Ehad)
xrange3 = [1E-6, 1.0]
yrange3 = [1E-6, 1.0]
yrange3[0] = xrange1[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01
# Out:
# exceed y=1

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange2, yrange2, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(x0, Q20, 'r')
#plt.plot(x1, Q21, 'r')
plt.plot(x2, Q22, 'r')
#plt.plot(x3, Q23, 'r')
#plt.plot(x4, Q24, 'r')
plt.plot(x5, Q25, 'r')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.plot(xm3, Q2m3, 'b')
plt.plot(xm4, Q2m4, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
#plt.figtext(0.78, 0.35, '1600', fontsize=8)
#plt.figtext(0.61, 0.15, '2000', fontsize=8)
plt.figtext(0.76, 0.165, '1500', fontsize=8)
plt.figtext(0.80, 0.14, '3000', fontsize=8)
#plt.figtext(0.69, 0.15, '4000', fontsize=8)
#plt.figtext(0.74, 0.20, '5000', fontsize=8)
plt.figtext(0.84, 0.165, '6000', fontsize=8)
plt.figtext(0.62, 0.15, '50', fontsize=8)
plt.figtext(0.68, 0.18, '200', fontsize=8)
plt.figtext(0.71, 0.24, '400', fontsize=8)
plt.figtext(0.74, 0.29, '750', fontsize=8)
#plt.figtext(0.75, 0.4, '1400', fontsize=8)
plt.grid()
plt.show()

# %%
Elep = 1500
Ehad = 7000
nx = 60
xmax = 1.0  # for E'> E
xmin = 1E-6 # For E' < E
Th1 = 177.9 # eta = -4
Th2 = 174.3 # eta = -3
Th3 = 164.6 # eta = -2
Th4 = 140.0 # eta = -1 
Th5 = 90.0 # eta = 0
Th6 = 40.4 # eta = 1
Th7 = 15.4 # eta = 2
Th8 = 5.7 # eta = 3
#Th7 = 2.1 # eta = 4
#Th8 = 0.772 # eta = 5
xmin1 = 1.0E-6
xmin2 = 3.0E-6
xmin3 = 1.0E-5
xmin4 = 3.0E-5
xmin5 = 7.0E-5
xmin6 = 2.0E-4
xmin7 = 5.0E-4
xmin8 = 2.0E-3
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.000001, 1.0]
yrange1 = [0.000001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [2E-6, 1.0]
yrange3 = [2E-6, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh1, Q2Th1, 'r')
plt.plot(xTh2, Q2Th2, 'r')
plt.plot(xTh3, Q2Th3, 'r')
plt.plot(xTh4, Q2Th4, 'r')
plt.plot(xTh5, Q2Th5, 'r')
plt.plot(xTh6, Q2Th6, 'r')
plt.plot(xTh7, Q2Th7, 'r')
plt.plot(xTh8, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.14, 0.18, '-4', fontsize=8)
plt.figtext(0.19, 0.18, '-3', fontsize=8)
plt.figtext(0.19, 0.18, '-3', fontsize=8)
plt.figtext(0.25, 0.18, '-2', fontsize=8)
plt.figtext(0.31, 0.18, '-1', fontsize=8)
plt.figtext(0.36, 0.18, '0', fontsize=8)
plt.figtext(0.41, 0.18, '1', fontsize=8)
plt.figtext(0.46, 0.18, '2', fontsize=8)
plt.figtext(0.52, 0.18, '3', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k')
plt.plot(xTh1, Q2Th1, 'r--')
plt.plot(xTh2, Q2Th2, 'r--')
plt.plot(xTh3, Q2Th3, 'r--')
plt.plot(xTh4, Q2Th4, 'r--')
plt.plot(xTh5, Q2Th5, 'r--')
plt.plot(xTh6, Q2Th6, 'r--')
plt.plot(xTh7, Q2Th7, 'r--')
plt.plot(xTh8, Q2Th8, 'r--')
plt.plot(xrange2, yrange2, 'k')
plt.plot(x0, Q20, 'b--')
#plt.plot(x1, Q21, 'b--')
plt.plot(x2, Q22, 'b--')
#plt.plot(x3, Q23, 'b--')
#plt.plot(x4, Q24, 'b--')
plt.plot(x5, Q25, 'b--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.plot(xm3, Q2m3, 'b--')
plt.plot(xm4, Q2m4, 'b--')
plt.yscale('log')
plt.xscale('log')
plt.title('LHmuC mu-p 1500 x 7000 GeV, Constant Ehad - Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
#plt.figtext(0.78, 0.35, '1600', fontsize=8)
#plt.figtext(0.61, 0.15, '2000', fontsize=8)
plt.figtext(0.76, 0.165, '1500', fontsize=8)
plt.figtext(0.80, 0.14, '3000', fontsize=8)
#plt.figtext(0.69, 0.15, '4000', fontsize=8)
#plt.figtext(0.74, 0.20, '5000', fontsize=8)
plt.figtext(0.84, 0.165, '6000', fontsize=8)
plt.figtext(0.62, 0.15, '50', fontsize=8)
plt.figtext(0.68, 0.18, '200', fontsize=8)
plt.figtext(0.71, 0.24, '400', fontsize=8)
plt.figtext(0.74, 0.29, '750', fontsize=8)
#plt.figtext(0.75, 0.4, '1400', fontsize=8)
plt.figtext(0.14, 0.17, '-4', fontsize=8)
plt.figtext(0.20, 0.17, '-3', fontsize=8)
plt.figtext(0.25, 0.17, '-2', fontsize=8)
plt.figtext(0.31, 0.17, '-1', fontsize=8)
plt.figtext(0.36, 0.17, '0', fontsize=8)
plt.figtext(0.41, 0.17, '1', fontsize=8)
plt.figtext(0.46, 0.17, '2', fontsize=8)
plt.figtext(0.52, 0.17, '3', fontsize=8)
plt.grid()
plt.show()

# %% [markdown]
# MuIC with upgraded hadron energy to 1 TeV

# %%
# E' < E always
Elep = 1000
Ehad = 1000
# E' < E
Em0 = 990
Em1 = 980
Em2 = 900
Em3 = 500
Em4 = 250

# %%
nx = 60
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
xmax0 = xmax
xmax1 = xmax
xmax2 = xmax
xmax3 = xmax
xmax4 = xmax
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logxmax3 = np.log(xmax3)
logxmax4 = np.log(xmax4)
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
logxm3 = [0] * nx
logxm4 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
xm3 = [0] * nx
xm4 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
Q2m3 = [0] * nx
Q2m4 = [0] * nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx
dlogxm3 = (np.log(xmax3)-np.log(xmin))/nx
dlogxm4 = (np.log(xmax4)-np.log(xmin))/nx

# %%
for i in range(nx):
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  logxm3[i] = logxmax3 - dlogxm3*i
  logxm4[i] = logxmax4 - dlogxm4*i
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  xm3[i] = np.exp(logxm3[i])
  xm4[i] = np.exp(logxm4[i])
  Q2m0[i] = Q2vsXEp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEp(xm2[i],Em2, Elep, Ehad)
  Q2m3[i] = Q2vsXEp(xm3[i],Em3, Elep, Ehad)
  Q2m4[i] = Q2vsXEp(xm4[i],Em4, Elep, Ehad)
# Out:
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# exceed y=1
# /var/folders/qb/dyk63sq96gs3fzj7h8qdcfvm0000gn/T/ipykernel_10082/3790795383.py:4: RuntimeWarning: divide by zero encountered in double_scalars
#   tempQ2 = ((1-Ep/Elep)/((1/(s*x))-(1/(4*Elep*Elep))))

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-5, 1.0]
yrange3 = [1E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
#plt.subplot(111)
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.plot(xm3, Q2m3, 'b')
#plt.plot(xm4, Q2m4, 'b')
plt.plot(xrange3, yrange3, 'k--')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant Elep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.23, 0.17, '990', fontsize=8)
plt.figtext(0.13, 0.22, '980', fontsize=8)
plt.figtext(0.23, 0.33, '900', fontsize=8)
plt.figtext(0.13, 0.33, '500', fontsize=8)
#plt.figtext(0.13, 0.335, '250')
plt.grid()
plt.show()

# %% [markdown]
# Now angles

# %%
Elep = 1000
Ehad = 1000
nx = 20
xmax = 1.0  # for E'> E
xmin = 4E-6 # For E' < E
Th0 = 179.962 # eta = -8
Th1 = 179.90 # eta = -7
Th2 = 179.72 # eta = -6
Th3 = 179.23 # eta = -5 
Th4 = 177.9 # eta = -4
Th5 = 174.3 # eta = -3
Th6 = 164.6 # eta = -2
Th7 = 139.6 # eta = -1
Th8 = 90.0 # eta = 0
#Th8 = 40.4 # eta = 1
dlogxTh = (np.log(xmax)-np.log(xmin))/nx
logxTh = [0] * nx
xTh = [0] * nx
Q2Th0 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh[i] = np.log(xmin) + dlogxTh*i
  xTh[i] = np.exp(logxTh[i])
  Q2Th0[i] = Q2vsXTh(xTh[i],Th0, Elep, Ehad)
  Q2Th1[i] = Q2vsXTh(xTh[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXTh(xTh[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXTh(xTh[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXTh(xTh[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXTh(xTh[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXTh(xTh[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXTh(xTh[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXTh(xTh[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.00001, 1.0]
yrange1 = [0.00001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-5, 1.0]
yrange3 = [1E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh, Q2Th0, 'r')
plt.plot(xTh, Q2Th1, 'r')
plt.plot(xTh, Q2Th2, 'r')
plt.plot(xTh, Q2Th3, 'r')
plt.plot(xTh, Q2Th4, 'r')
plt.plot(xTh, Q2Th5, 'r')
plt.plot(xTh, Q2Th6, 'r')
plt.plot(xTh, Q2Th7, 'r')
plt.plot(xTh, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant Eta')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.15, '-8', fontsize=8)
plt.figtext(0.84, 0.25, '-7', fontsize=8)
plt.figtext(0.84, 0.34, '-6', fontsize=8)
plt.figtext(0.84, 0.42, '-5', fontsize=8) 
plt.figtext(0.84, 0.51, '-4', fontsize=8) 
plt.figtext(0.84, 0.59, '-3', fontsize=8) 
plt.figtext(0.84, 0.68, '-2', fontsize=8) 
plt.figtext(0.84, 0.75, '-1', fontsize=8)
plt.figtext(0.84, 0.80, '0', fontsize=8) 
plt.grid()
plt.show()

# %% [markdown]
# Combined plot

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k')
#Eta values
plt.plot(xTh, Q2Th0, 'r--')
plt.plot(xTh, Q2Th1, 'r--')
plt.plot(xTh, Q2Th2, 'r--')
plt.plot(xTh, Q2Th3, 'r--')
plt.plot(xTh, Q2Th4, 'r--')
plt.plot(xTh, Q2Th5, 'r--')
plt.plot(xTh, Q2Th6, 'r--')
plt.plot(xTh, Q2Th7, 'r--')
plt.plot(xTh, Q2Th8, 'r--')
# Energies
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.plot(xm3, Q2m3, 'b--')
#plt.plot(xm4, Q2m4, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant E - Eta_lep')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.84, 0.18, '-8', fontsize=8)
plt.figtext(0.84, 0.26, '-7', fontsize=8)
plt.figtext(0.84, 0.35, '-6', fontsize=8)
plt.figtext(0.84, 0.43, '-5', fontsize=8) 
plt.figtext(0.84, 0.52, '-4', fontsize=8) 
plt.figtext(0.84, 0.61, '-3', fontsize=8) 
plt.figtext(0.86, 0.68, '-2', fontsize=8) 
plt.figtext(0.86, 0.76, '-1', fontsize=8)
plt.figtext(0.87, 0.80, '0', fontsize=8) 
plt.figtext(0.14, 0.14, '990', fontsize=8)
plt.figtext(0.14, 0.20, '980', fontsize=8)
plt.figtext(0.14, 0.27, '900', fontsize=8)
plt.figtext(0.14, 0.32, '500', fontsize=8)
#plt.figtext(0.13, 0.335, '250')
plt.grid()
plt.show()

# %% [markdown]
# Hadron variables

# %%
Elep = 1000
Ehad = 1000
Em0 = 274.8
Em1 = 160
Em2 = 40
Em3 = 10
Em4 = 750
Em5 = 500

# %%
nx = 60
xmax = 1.0  # for E'> E
xmin = 1E-5 # For E' < E
xmax0 = Em0/Ehad*0.9999
xmax1 = Em1/Ehad*0.9999
xmax2 = Em2/Ehad*0.9999
xmax3 = Em3/Ehad*0.999
xmax4 = Em4/Ehad*0.9999
xmax5 = Em5/Ehad*0.9999
logxmax0 = np.log(xmax0)
logxmax1 = np.log(xmax1)
logxmax2 = np.log(xmax2)
logxmax3 = np.log(xmax3)
logxmax4 = np.log(xmax4)
logxmax5 = np.log(xmax5)
logxm0 = [0] * nx
logxm1 = [0] * nx
logxm2 = [0] * nx
logxm3 = [0] * nx
logxm4 = [0] * nx
logxm5 = [0] * nx
xm0 = [0] * nx
xm1 = [0] * nx
xm2 = [0] * nx
xm3 = [0] * nx
xm4 = [0] * nx
xm5 = [0] * nx
Q2m0 = [0] * nx
Q2m1 = [0] * nx
Q2m2 = [0] * nx
Q2m3 = [0] * nx
Q2m4 = [0] * nx
Q2m5 = [0] * nx
dlogxm0 = (np.log(xmax0)-np.log(xmin))/nx
dlogxm1 = (np.log(xmax1)-np.log(xmin))/nx
dlogxm2 = (np.log(xmax2)-np.log(xmin))/nx
dlogxm3 = (np.log(xmax3)-np.log(xmin))/nx
dlogxm4 = (np.log(xmax4)-np.log(xmin))/nx
dlogxm5 = (np.log(xmax5)-np.log(xmin))/nx

# %%
for i in range(nx):
  logxm0[i] = logxmax0 - dlogxm0*i
  logxm1[i] = logxmax1 - dlogxm1*i
  logxm2[i] = logxmax2 - dlogxm2*i
  logxm3[i] = logxmax3 - dlogxm3*i
  logxm4[i] = logxmax4 - dlogxm4*i
  logxm5[i] = logxmax5 - dlogxm5*i
  xm0[i] = np.exp(logxm0[i])
  xm1[i] = np.exp(logxm1[i])
  xm2[i] = np.exp(logxm2[i])
  xm3[i] = np.exp(logxm3[i])
  xm4[i] = np.exp(logxm4[i])
  xm5[i] = np.exp(logxm5[i])
  Q2m0[i] = Q2vsXEhadp(xm0[i],Em0, Elep, Ehad)
  Q2m1[i] = Q2vsXEhadp(xm1[i],Em1, Elep, Ehad)
  Q2m2[i] = Q2vsXEhadp(xm2[i],Em2, Elep, Ehad)
  Q2m3[i] = Q2vsXEhadp(xm3[i],Em3, Elep, Ehad)
  Q2m4[i] = Q2vsXEhadp(xm4[i],Em4, Elep, Ehad)
  Q2m5[i] = Q2vsXEhadp(xm5[i],Em5, Elep, Ehad)

# %%
xrange1 = [1E-5, 1.0]
yrange1 = [1E-5, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [1E-5, 1.0]
yrange3 = [1E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xm0, Q2m0, 'b')
plt.plot(xm1, Q2m1, 'b')
plt.plot(xm2, Q2m2, 'b')
plt.plot(xm3, Q2m3, 'b')
plt.plot(xm4, Q2m4, 'b')
plt.plot(xm5, Q2m5, 'b')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant Ehad')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.85, 0.50, '750', fontsize=8)
plt.figtext(0.83, 0.44, '500', fontsize=8)
plt.figtext(0.80, 0.37, '275', fontsize=8)
plt.figtext(0.76, 0.31, '160', fontsize=8)
plt.figtext(0.68, 0.25, '40', fontsize=8)
plt.figtext(0.6, 0.22, '10', fontsize=8)
plt.grid()
plt.show()

# %%
Elep = 1000
Ehad = 1000
nx = 60
xmax = 1.0  # for E'> E
xmin = 4E-5 # For E' < E
Th1 = 177.9 # eta = -4
Th2 = 174.3 # eta = -3
Th3 = 164.6 # eta = -2
Th4 = 140.0 # eta = -1 
Th5 = 90.0 # eta = 0
Th6 = 40.4 # eta = 1
Th7 = 15.4 # eta = 2
Th8 = 5.7 # eta = 3
#Th7 = 2.1 # eta = 4
#Th8 = 0.772 # eta = 5
xmin1 = xmin
xmin2 = xmin
xmin3 = 0.0001
xmin4 = 0.0004
xmin5 = 0.001
xmin6 = 0.004
xmin7 = 0.01
xmin8 = 0.04
dlogxTh1 = (np.log(xmax)-np.log(xmin1))/nx
dlogxTh2 = (np.log(xmax)-np.log(xmin2))/nx
dlogxTh3 = (np.log(xmax)-np.log(xmin3))/nx
dlogxTh4 = (np.log(xmax)-np.log(xmin4))/nx
dlogxTh5 = (np.log(xmax)-np.log(xmin5))/nx
dlogxTh6 = (np.log(xmax)-np.log(xmin6))/nx
dlogxTh7 = (np.log(xmax)-np.log(xmin7))/nx
dlogxTh8 = (np.log(xmax)-np.log(xmin8))/nx
logxTh1 = [0] * nx
logxTh2 = [0] * nx
logxTh3 = [0] * nx
logxTh4 = [0] * nx
logxTh5 = [0] * nx
logxTh6 = [0] * nx
logxTh7 = [0] * nx
logxTh8 = [0] * nx
xTh1 = [0] * nx
xTh2 = [0] * nx
xTh3 = [0] * nx
xTh4 = [0] * nx
xTh5 = [0] * nx
xTh6 = [0] * nx
xTh7 = [0] * nx
xTh8 = [0] * nx
Q2Th1 = [0] * nx
Q2Th2 = [0] * nx
Q2Th3 = [0] * nx
Q2Th4 = [0] * nx
Q2Th5 = [0] * nx
Q2Th6 = [0] * nx
Q2Th7 = [0] * nx
Q2Th8 = [0] * nx
for i in range(nx):
  logxTh1[i] = np.log(xmin1) + dlogxTh1*i
  logxTh2[i] = np.log(xmin2) + dlogxTh2*i
  logxTh3[i] = np.log(xmin3) + dlogxTh3*i
  logxTh4[i] = np.log(xmin4) + dlogxTh4*i
  logxTh5[i] = np.log(xmin5) + dlogxTh5*i
  logxTh6[i] = np.log(xmin6) + dlogxTh6*i
  logxTh7[i] = np.log(xmin7) + dlogxTh7*i
  logxTh8[i] = np.log(xmin8) + dlogxTh8*i
  xTh1[i] = np.exp(logxTh1[i])
  xTh2[i] = np.exp(logxTh2[i])
  xTh3[i] = np.exp(logxTh3[i])
  xTh4[i] = np.exp(logxTh4[i])
  xTh5[i] = np.exp(logxTh5[i])
  xTh6[i] = np.exp(logxTh6[i])
  xTh7[i] = np.exp(logxTh7[i])
  xTh8[i] = np.exp(logxTh8[i])
  Q2Th1[i] = Q2vsXThHad(xTh1[i],Th1, Elep, Ehad)
  Q2Th2[i] = Q2vsXThHad(xTh2[i],Th2, Elep, Ehad)
  Q2Th3[i] = Q2vsXThHad(xTh3[i],Th3, Elep, Ehad)
  Q2Th4[i] = Q2vsXThHad(xTh4[i],Th4, Elep, Ehad)
  Q2Th5[i] = Q2vsXThHad(xTh5[i],Th5, Elep, Ehad)
  Q2Th6[i] = Q2vsXThHad(xTh6[i],Th6, Elep, Ehad)
  Q2Th7[i] = Q2vsXThHad(xTh7[i],Th7, Elep, Ehad)
  Q2Th8[i] = Q2vsXThHad(xTh8[i],Th8, Elep, Ehad)

# %%
xrange1 = [0.00001, 1.0]
yrange1 = [0.00001, 1.0]
yrange1[0] = xrange1[0]*4*Elep*Ehad
yrange1[1] = 4*Elep*Ehad
xrange3 = [4E-5, 1.0]
yrange3 = [4E-5, 1.0]
yrange3[0] = xrange3[0]*4*Elep*Ehad*0.01
yrange3[1] = 4*Elep*Ehad*0.01

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k--')
plt.plot(xTh1, Q2Th1, 'r')
plt.plot(xTh2, Q2Th2, 'r')
plt.plot(xTh3, Q2Th3, 'r')
plt.plot(xTh4, Q2Th4, 'r')
plt.plot(xTh5, Q2Th5, 'r')
plt.plot(xTh6, Q2Th6, 'r')
plt.plot(xTh7, Q2Th7, 'r')
#plt.plot(xTh8, Q2Th8, 'r')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.22, 0.23, '-4', fontsize=8)
plt.figtext(0.26, 0.19, '-3', fontsize=8)
plt.figtext(0.32, 0.18, '-2', fontsize=8)
plt.figtext(0.38, 0.18, '-1', fontsize=8)
plt.figtext(0.46, 0.18, '0', fontsize=8)
plt.figtext(0.53, 0.18, '1', fontsize=8)
plt.figtext(0.6, 0.18, '2', fontsize=8)
#plt.figtext(0.67, 0.18, '3', fontsize=8)
plt.grid()
plt.show()

# %%
plt.plot(xrange1, yrange1, 'k')
plt.plot(xrange3, yrange3, 'k')
plt.plot(xTh1, Q2Th1, 'r--')
plt.plot(xTh2, Q2Th2, 'r--')
plt.plot(xTh3, Q2Th3, 'r--')
plt.plot(xTh4, Q2Th4, 'r--')
plt.plot(xTh5, Q2Th5, 'r--')
plt.plot(xTh6, Q2Th6, 'r--')
plt.plot(xTh7, Q2Th7, 'r--')
#plt.plot(xTh8, Q2Th8, 'r--')
plt.plot(xm0, Q2m0, 'b--')
plt.plot(xm1, Q2m1, 'b--')
plt.plot(xm2, Q2m2, 'b--')
plt.plot(xm3, Q2m3, 'b--')
plt.plot(xm4, Q2m4, 'b--')
plt.plot(xm5, Q2m5, 'b--')
plt.yscale('log')
plt.xscale('log')
plt.title('MuIC2 mu-p 1000 x 1000 GeV, Constant Ehad - Eta_had')
plt.ylabel('Q2')
plt.xlabel('x')
plt.figtext(0.24, 0.30, '-4', fontsize=8)
plt.figtext(0.26, 0.24, '-3', fontsize=8)
plt.figtext(0.32, 0.24, '-2', fontsize=8)
plt.figtext(0.38, 0.24, '-1', fontsize=8)
plt.figtext(0.46, 0.24, '0', fontsize=8)
plt.figtext(0.53, 0.24, '1', fontsize=8)
plt.figtext(0.6, 0.27, '2', fontsize=8)
#plt.figtext(0.67, 0.27, '3')
plt.figtext(0.85, 0.50, '750', fontsize=8)
plt.figtext(0.83, 0.44, '500', fontsize=8)
plt.figtext(0.80, 0.37, '275', fontsize=8)
plt.figtext(0.76, 0.31, '160', fontsize=8)
plt.figtext(0.68, 0.24, '40', fontsize=8)
plt.figtext(0.6, 0.21, '10', fontsize=8)
plt.grid()
plt.show()
